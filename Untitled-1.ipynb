# %%
import pandas as pd

df = pd.read_csv("df.csv", sep=";")#Brug det lokale dataset
print(df.head)
#print(df.info)
#print(df["Gender"].value_counts())
#print(df.describe)
# Out:
# <bound method NDFrame.head of       Marital status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance\t  Previous qualification  \
# 0                                1                       1
# 1                                1                       1
# 2                                1                       1
# 3                                1                       1
# 4                                0                       1
# ...                            ...                     ...
# 4419                             1                       1
# 4420                             1                       1
# 4421                             1                       1
# 4422                             1                       1
# 4423                             1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                              122.0            1                      19
# 1                              160.0            1                       1
# 2                              122.0            1                      37
# 3                              122.0            1                      38
# 4                              100.0            1                      37
# ...                              ...          ...                     ...
# 4419                           125.0            1                       1
# 4420                           120.0          105                       1
# 4421                           154.0            1                      37
# 4422                           180.0            1                      37
# 4423                           152.0           22                      38
#
#       Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                         12  ...                                    0
# 1                          3  ...                                    0
# 2                         37  ...                                    0
# 3                         37  ...                                    0
# 4                         38  ...                                    0
# ...                      ...  ...                                  ...
# 4419                       1  ...                                    0
# 4420                       1  ...                                    0
# 4421                      37  ...                                    0
# 4422                      37  ...                                    0
# 4423                      37  ...                                    0
#
#       Curricular units 2nd sem (enrolled)  \
# 0                                       0
# 1                                       6
# 2                                       6
# 3                                       6
# 4                                       6
# ...                                   ...
# 4419                                    6
# 4420                                    6
# 4421                                    8
# 4422                                    5
# 4423                                    6
#
#       Curricular units 2nd sem (evaluations)  \
# 0                                          0
# 1                                          6
# 2                                          0
# 3                                         10
# 4                                          6
# ...                                      ...
# 4419                                       8
# 4420                                       6
# 4421                                       9
# 4422                                       6
# 4423                                       6
#
#       Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                       0                          0.000000
# 1                                       6                         13.666667
# 2                                       0                          0.000000
# 3                                       5                         12.400000
# 4                                       6                         13.000000
# ...                                   ...                               ...
# 4419                                    5                         12.666667
# 4420                                    2                         11.000000
# 4421                                    1                         13.500000
# 4422                                    5                         12.000000
# 4423                                    6                         13.000000
#
#       Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                                  0               10.8
# 1                                                  0               13.9
# 2                                                  0               10.8
# 3                                                  0                9.4
# 4                                                  0               13.9
# ...                                              ...                ...
# 4419                                               0               15.5
# 4420                                               0               11.1
# 4421                                               0               13.9
# 4422                                               0                9.4
# 4423                                               0               12.7
#
#       Inflation rate   GDP    Target
# 0                1.4  1.74   Dropout
# 1               -0.3  0.79  Graduate
# 2                1.4  1.74   Dropout
# 3               -0.8 -3.12  Graduate
# 4               -0.3  0.79  Graduate
# ...              ...   ...       ...
# 4419             2.8 -4.06  Graduate
# 4420             0.6  2.02   Dropout
# 4421            -0.3  0.79   Dropout
# 4422            -0.8 -3.12  Graduate
# 4423             3.7 -1.70  Graduate
#
# [4424 rows x 37 columns]>

# %%
import matplotlib.pyplot as plt

# extra code – the next 5 lines define the default font sizes
plt.rc('font', size=10)
plt.rc('axes', labelsize=8, titlesize=10)
plt.rc('legend', fontsize=10)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

df.hist(bins=50, figsize=(12, 8))#Make histograms
plt.show()
# Out:
# C:\Users\Jonas Lind\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
category_counts = df['Target'].value_counts()
print(category_counts)
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder

collums_to_encode = ["Application mode", "Course", "Nacionality", "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation"]

df_oneHotEncoded = pd.get_dummies(df, columns= collums_to_encode)#One hot ecodes the specified columns

#print(df_oneHotEncoded)

# %% [markdown]
# Now I split the data into a test and train set with a 80-20 distribution

# %%
import numpy as np

np.random.seed(42)
def shuffle_and_split_data(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]
#train_set, test_set = shuffle_and_split_data(df_oneHotEncoded, 0.2) #Uncomment to see results with one hot encoding
train_set, test_set = shuffle_and_split_data(df, 0.2) #Uncomment to see results without one hot encoding
#print(len(train_set))
#print(len(test_set))
y_train = train_set['Target']#Splits the data into a train set and a  test set
x_train = train_set.drop(columns=['Target'])
y_test = test_set['Target']
x_test = test_set.drop(columns=['Target'])
#print(x_train.head)

# %% [markdown]
# It was shown previously that the data is imbalanced, Therefore I use SMOTE to create synthetic data

# %%
from imblearn.over_sampling import SMOTE


smote = SMOTE(sampling_strategy='auto', random_state=42)

# Apply SMOTE to create synthetic samples
x_SMOTED_train, y_SMOTED_train = smote.fit_resample(x_train, y_train)
x_SMOTED_test, y_SMOTED_test = smote.fit_resample(x_test, y_test)

# Display distribution before and after SMOTE
print("Test distribution before SMOTE:", {label: count for label, count in zip(*np.unique(y_train, return_counts=True))})
print("Test distribution after SMOTE:", {label: count for label, count in zip(*np.unique(y_SMOTED_train, return_counts=True))})
print("Test distribution before SMOTE:", {label: count for label, count in zip(*np.unique(y_test, return_counts=True))})
print("Test distribution after SMOTE:", {label: count for label, count in zip(*np.unique(y_SMOTED_test, return_counts=True))})
# Out:
# Test distribution before SMOTE: {'Dropout': 1105, 'Enrolled': 643, 'Graduate': 1792}
# Test distribution after SMOTE: {'Dropout': 1792, 'Enrolled': 1792, 'Graduate': 1792}
# Test distribution before SMOTE: {'Dropout': 316, 'Enrolled': 151, 'Graduate': 417}
# Test distribution after SMOTE: {'Dropout': 417, 'Enrolled': 417, 'Graduate': 417}

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier

rnd_clf = RandomForestClassifier(n_estimators=500, random_state=42)
iris = load_iris(as_frame=True)
rnd_clf.fit(x_SMOTED_train, y_SMOTED_train)
for score, name in zip(rnd_clf.feature_importances_, x_train.columns):
    print(round(score, 2), name)#calculates importance of each feature
# Out:
# 0.0 Marital status
# 0.02 Application mode
# 0.01 Application order
# 0.04 Course
# 0.0 Daytime/evening attendance
# 0.01 Previous qualification
# 0.04 Previous qualification (grade)
# 0.0 Nacionality
# 0.02 Mother's qualification
# 0.02 Father's qualification
# 0.03 Mother's occupation
# 0.03 Father's occupation
# 0.04 Admission grade
# 0.01 Displaced
# 0.0 Educational special needs
# 0.01 Debtor
# 0.05 Tuition fees up to date
# 0.01 Gender
# 0.03 Scholarship holder
# 0.03 Age at enrollment
# 0.0 International
# 0.01 Curricular units 1st sem (credited)
# 0.02 Curricular units 1st sem (enrolled)
# 0.03 Curricular units 1st sem (evaluations)
# 0.08 Curricular units 1st sem (approved)
# 0.06 Curricular units 1st sem (grade)
# 0.0 Curricular units 1st sem (without evaluations)
# 0.01 Curricular units 2nd sem (credited)
# 0.02 Curricular units 2nd sem (enrolled)
# 0.04 Curricular units 2nd sem (evaluations)
# 0.14 Curricular units 2nd sem (approved)
# 0.1 Curricular units 2nd sem (grade)
# 0.0 Curricular units 2nd sem (without evaluations)
# 0.03 Unemployment rate
# 0.03 Inflation rate
# 0.03 GDP

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

log_reg = LogisticRegression(max_iter=10000)
log_reg.fit(x_SMOTED_train, y_SMOTED_train)
y_pred_log_reg = log_reg.predict(x_SMOTED_test)

accuracy = accuracy_score(y_SMOTED_test, y_pred_log_reg)
f1 = f1_score(y_SMOTED_test, y_pred_log_reg, average='macro') #micro macro or weighted 
print("Accuracy on test data:", accuracy)#random forest classification results
print("f1 score =", f1)
# Out:
# Accuracy on test data: 0.7561950439648282
# f1 score = 0.7562691750157599

# %%
rnd_clf = RandomForestClassifier(n_estimators=500, max_leaf_nodes=16, n_jobs=-1, random_state=42)
rnd_clf.fit(x_SMOTED_train, y_SMOTED_train)
y_pred_rf = rnd_clf.predict(x_SMOTED_test)
accuracy = accuracy_score(y_SMOTED_test, y_pred_rf)
f1 = f1_score(y_SMOTED_test, y_pred_rf, average='macro') #micro macro or weighted 
print("Accuracy on test data:", accuracy)#random forest classification results
print("f1 score =", f1)
# Out:
# Accuracy on test data: 0.7234212629896083
# f1 score = 0.722094429759912

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

bag_clf = BaggingClassifier(DecisionTreeClassifier(max_features=int(np.sqrt(x_train.shape[1])), max_leaf_nodes=16), n_estimators=500, n_jobs=-1, random_state=42)
bag_clf.fit(x_SMOTED_train, y_SMOTED_train)
y_pred_bag = bag_clf.predict(x_SMOTED_test)
accuracy = accuracy_score(y_SMOTED_test, y_pred_bag)
f1 = f1_score(y_SMOTED_test, y_pred_bag, average='macro') #micro macro or weighted
print("Accuracy on test data:", accuracy) #Bagging classifier outcome 
print("f1 score =", f1)
# Out:
# Accuracy on test data: 0.7274180655475619
# f1 score = 0.7256202366059651

# %%
from sklearn.ensemble import AdaBoostClassifier


ada_clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), n_estimators=500, learning_rate= 0.5, random_state=42)
ada_clf.fit(x_SMOTED_train, y_SMOTED_train)
y_pred_ada = ada_clf.predict(x_SMOTED_test)
accuracy = accuracy_score(y_SMOTED_test, y_pred_ada)
f1 = f1_score(y_SMOTED_test, y_pred_ada, average='macro') #micro macro or weighted
print("Accuracy on test data:", accuracy) #Adaboost outcome
print("f1 score =", f1)
# Out:
# Accuracy on test data: 0.7673860911270983
# f1 score = 0.7667050078853178
